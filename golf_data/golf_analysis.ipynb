# %% [markdown]
# who scores the best on par 3s?
# who scores the best on par 4s?
# who scores the best on par 5s?
# correlation between driving accuracy and score?
# correlation between GIR and score?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('pga_tour_data_2015_2022.csv')
data.head()
# Out:
#   Player_initial_last  tournament id  player id  hole_par  strokes  hole_DKP  \
# 0            A. Ancer      401353224       9261       288      289      60.0
# 1           A. Hadwin      401353224       5548       288      286      72.5
# 2           A. Lahiri      401353224       4989       144      147      21.5
# 3             A. Long      401353224       6015       144      151      20.5
# 4            A. Noren      401353224       3832       144      148      23.5
#
#    hole_FDP  hole_SDP  streak_DKP  streak_FDP  ...  purse  season  no_cut  \
# 0      51.1        56           3         7.6  ...   12.0    2022       0
# 1      61.5        61           8        13.0  ...   12.0    2022       0
# 2      17.4        27           0         0.0  ...   12.0    2022       0
# 3      13.6        17           0         0.4  ...   12.0    2022       0
# 4      18.1        23           0         1.2  ...   12.0    2022       0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36864 entries, 0 to 36863
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player_initial_last  36864 non-null  object
#  1   tournament id        36864 non-null  int64
#  2   player id            36864 non-null  int64
#  3   hole_par             36864 non-null  int64
#  4   strokes              36864 non-null  int64
#  5   hole_DKP             36864 non-null  float64
#  6   hole_FDP             36864 non-null  float64
#  7   hole_SDP             36864 non-null  int64
#  8   streak_DKP           36864 non-null  int64
#  9   streak_FDP           36864 non-null  float64
#  10  streak_SDP           36864 non-null  int64
#  11  n_rounds             36864 non-null  int64
#  12  made_cut             36864 non-null  int64
#  13  pos                  21317 non-null  float64
#  14  finish_DKP           36864 non-null  int64
# ...

# %%
data.columns = [c.lower().replace(' ', '_') for c in golf_data.columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36864 entries, 0 to 36863
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player_initial_last  36864 non-null  object
#  1   tournament_id        36864 non-null  int64
#  2   player_id            36864 non-null  int64
#  3   hole_par             36864 non-null  int64
#  4   strokes              36864 non-null  int64
#  5   hole_dkp             36864 non-null  float64
#  6   hole_fdp             36864 non-null  float64
#  7   hole_sdp             36864 non-null  int64
#  8   streak_dkp           36864 non-null  int64
#  9   streak_fdp           36864 non-null  float64
#  10  streak_sdp           36864 non-null  int64
#  11  n_rounds             36864 non-null  int64
#  12  made_cut             36864 non-null  int64
#  13  pos                  21317 non-null  float64
#  14  finish_dkp           36864 non-null  int64
# ...

# %%
data.tournament_name.unique()
# Out:
# array(['The Memorial Tournament pres. by Nationwide',
#        'Charles Schwab Challenge', 'PGA Championship',
#        'AT&T Byron Nelson', 'Wells Fargo Championship', 'Mexico Open',
#        'RBC Heritage', 'Masters Tournament', 'Valero Texas Open',
#        'Corales Puntacana Resort & Club Championship',
#        'Valspar Championship', 'The Players Championship',
#        'Puerto Rico Open',
#        'Arnold Palmer Invitational Pres. by Mastercard',
#        'The Honda Classic', 'The Genesis Invitational',
#        'Waste Management Phoenix Open', 'AT&T Pebble Beach Pro-Am',
#        'Farmers Insurance Open', 'The American Express',
#        'Sony Open in Hawaii', 'Sentry Tournament of Champions',
#        'Hero World Challenge', 'The RSM Classic', 'Houston Open',
#        'Mayakoba Golf Classic', 'Bermuda Championship',
#        'The ZOZO Championship', 'The CJ Cup @ Summit',
#        'Shriners Hospital for Children Open',
# ...

# %%
masters = data.loc[data['tournament_name'] == 'Masters Tournament']

# %%
masters.head()
# Out:
#     player_initial_last  tournament_id  player_id  hole_par  strokes  \
# 878            A. Ancer      401353232       9261       144      151
# 879            A. Scott      401353232        388       288      302
# 880       B. DeChambeau      401353232      10046       144      156
# 881           B. Harman      401353232       1225       144      149
# 882         B. Horschel      401353232       1651       288      296
#
#      hole_dkp  hole_fdp  hole_sdp  streak_dkp  streak_fdp  ...  purse  season  \
# 878      23.0      13.7        18           0         6.4  ...   15.0    2022
# 879      43.5      28.4        38           0         1.2  ...   15.0    2022
# 880      12.0       1.8        12           0         0.2  ...   15.0    2022
# 881      27.0      18.5        22           0         0.4  ...   15.0    2022
# 882      49.5      38.9        43           0         8.6  ...   15.0    2022
#
#      no_cut  finish  sg_putt  sg_arg  sg_app  sg_ott  sg_t2g  sg_total
# ...

# %%
masters.columns.tolist()
# Out:
# ['player_initial_last',
#  'tournament_id',
#  'player_id',
#  'hole_par',
#  'strokes',
#  'hole_dkp',
#  'hole_fdp',
#  'hole_sdp',
#  'streak_dkp',
#  'streak_fdp',
#  'streak_sdp',
#  'n_rounds',
#  'made_cut',
#  'pos',
#  'finish_dkp',
#  'finish_fdp',
#  'finish_sdp',
#  'total_dkp',
#  'total_fdp',
#  'total_sdp',
#  'player',
#  'unnamed:_2',
#  'unnamed:_3',
#  'unnamed:_4',
#  'tournament_name',
#  'course',
#  'date',
#  'purse',
#  'season',
#  'no_cut',
#  'finish',
#  'sg_putt',
#  'sg_arg',
#  'sg_app',
#  'sg_ott',
#  'sg_t2g',
#  'sg_total']
